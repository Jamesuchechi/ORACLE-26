# %% [markdown]
# # ◈ ORACLE-26 | Vertical I: Sports Signal
# ## 01: Elo, Form, and Predictive Modeling
# ---
# This notebook explores the core predictive engine for Vertical I of the CONFLUX thesis. We analyze historical results, calculate dynamic Elo ratings, and fit a Dixon-Coles Poisson model to estimate win probabilities for the 2026 field.
#
# > **The Analyst's Perspective:** While pure sports data (Elo/Form) is the standard for prediction, ORACLE-26 treats this as only the *baseline*. A team's performance is not a closed system; it is subject to economic stress, climate risk, and cultural pressure. We establish the sports baseline here before fusing it with outside signals in later stages.

# %%
import os
import pandas as pd
import numpy as np
import sys
from pathlib import Path

# Ensure project root is in path
sys.path.append(str(Path(os.getcwd()).parent))

from src.data.sports import SportsSignalEngine
from src.constants import ALL_WC_TEAMS

engine = SportsSignalEngine()
print(f"Initialized engine with {len(ALL_WC_TEAMS)} World Cup teams.")

# %% [markdown]
# ### 1. Data Loading & Cleaning
# We pull results from the international football dataset. Note that we filter for the modern era (post-2010) to ensure signal relevance.

# %%
results = engine.load_results()
print(f"Loaded {len(results)} historical matches.")
results.head()

# %% [markdown]
# ### 2. Feature Engineering: Elo & Form
# We calculate momentum-based signals. The **Elo** score captures historical strength, while the **Form** score captures the second-order derivative (velocity of improvement).

# %%
features = engine.extract_features()
print("Features extracted for all 48 teams.")
features.sort_values("elo", ascending=False).head(10)

# %% [markdown]
# ### 3. Predictive Modeling (Dixon-Coles)
# We fit a Dixon-Coles model to account for low-scoring match dynamics and home-field advantage (which is exceptionally high in 2026 due to travel logistics).

# %%
model = engine.fit_poisson()
print("Poisson model fitted. System ready for fusion.")
